# %%
import dash
import dash_core_components as dcc
import dash_html_components as htaml
import pandas as pd
from dash.dependencies import Input, Output
import plotly.express as px

# %%
# Dash initialisation
app_fifa_dash = dash.Dash(__name__)

# %%
# Load data
group_stats_path = '/Users/vishalsehgal/Documents/Masters/Data Visualisation/DVProject/Data/group_stats.csv'
team_data_file_path = '/Users/vishalsehgal/Documents/Masters/Data Visualisation/DVProject/Data/team_data.csv'
df_group_stats = pd.read_csv(group_stats_path)
df_team_data = pd.read_csv(team_data_file_path)

# %%
# Removing the first column from df_group_stats
df_group_stats = df_group_stats.iloc[:, 1:]
df_group_stats.head()
# Out:
#    group  rank         team  matches_played  wins  draws  losses  \
# 0      1     1  Netherlands               3     2      1       0
# 1      1     2      Senegal               3     2      0       1
# 2      1     3      Ecuador               3     1      1       1
# 3      1     4        Qatar               3     0      0       3
# 4      2     1      England               3     2      1       0
#
#    goals_scored  goals_against  goal_difference  points  expected_goal_scored  \
# 0             5              1                4       7                   2.4
# 1             5              4                1       6                   3.8
# 2             4              3                1       4                   3.7
# 3             1              7               -6       0                   1.4
# 4             9              2                7       7                   5.2
#
#    exp_goal_conceded  exp_goal_difference  exp_goal_difference_per_90
# 0                2.7                 -0.3                       -0.11
# 1                2.5                  1.3                        0.43
# 2                2.6                  1.2                        0.39
# 3                3.5                 -2.1                       -0.71
# 4                2.3                  2.9                        0.97

# %%
df_team_data.head()
# Out:
#         team  players_used  avg_age  possession  games  games_starts  minutes  \
# 0  Argentina            24     28.4        57.4      7            77      690
# 1  Australia            20     28.7        37.8      4            44      360
# 2    Belgium            20     30.6        57.0      3            33      270
# 3     Brazil            26     28.5        56.2      5            55      480
# 4   Cameroon            22     28.0        41.7      3            33      270
#
#    minutes_90s  goals  assists  ...  fouls  fouled  offsides  pens_won  \
# 0          7.7     15        8  ...    100     115        23         5
# 1          4.0      3        3  ...     52      34         1         0
# 2          3.0      1        1  ...     30      35         3         0
# 3          5.3      8        6  ...     63      74         8         1
# 4          3.0      4        4  ...     32      38         2         0
#
#    pens_conceded  own_goals  ball_recoveries  aerials_won  aerials_lost  \
# 0              2          1              357           83            90
# 1              0          0              200           72            72
# 2              1          0              132           33            28
# 3              0          0              271           43            56
# 4              0          0              142           42            36
#
#    aerials_won_pct
# 0             48.0
# 1             50.0
# 2             54.1
# 3             43.4
# 4             53.8
#
# [5 rows x 189 columns]

# %%
# connect df using team column
df_merged = pd.merge(df_group_stats, df_team_data, on='team', how='inner')

# Display the first few rows of the merged DataFrame to check
df_merged
# Out:
#     group  rank            team  matches_played  wins  draws  losses  \
# 0       1     1     Netherlands               3     2      1       0
# 1       1     2         Senegal               3     2      0       1
# 2       1     3         Ecuador               3     1      1       1
# 3       1     4           Qatar               3     0      0       3
# 4       2     1         England               3     2      1       0
# 5       2     2   United States               3     1      2       0
# 6       2     4           Wales               3     0      1       2
# 7       3     1       Argentina               3     2      0       1
# 8       3     2          Poland               3     1      1       1
# 9       3     3          Mexico               3     1      1       1
# 10      3     4    Saudi Arabia               3     1      0       2
# 11      4     1          France               3     2      0       1
# 12      4     2       Australia               3     2      0       1
# 13      4     3         Tunisia               3     1      1       1
# 14      4     4         Denmark               3     0      1       2
# 15      5     1           Japan               3     2      0       1
# 16      5     2           Spain               3     1      1       1
# 17      5     3         Germany               3     1      1       1
# 18      5     4      Costa Rica               3     1      0       2
# 19      6     1         Morocco               3     2      1       0
# 20      6     2         Croatia               3     1      2       0
# 21      6     3         Belgium               3     1      1       1
# 22      6     4          Canada               3     0      0       3
# 23      7     1          Brazil               3     2      0       1
# 24      7     2     Switzerland               3     2      0       1
# 25      7     3        Cameroon               3     1      1       1
# 26      7     4          Serbia               3     0      1       2
# 27      8     1        Portugal               3     2      0       1
# 28      8     2  Korea Republic               3     1      1       1
# 29      8     3         Uruguay               3     1      1       1
# 30      8     4           Ghana               3     1      0       2
#
#     goals_scored  goals_against  goal_difference  ...  fouls  fouled  \
# 0              5              1                4  ...     87      50
# 1              5              4                1  ...     48      57
# 2              4              3                1  ...     50      37
# 3              1              7               -6  ...     31      45
# 4              9              2                7  ...     53      65
# 5              2              1                1  ...     45      40
# 6              1              6               -5  ...     35      33
# 7              5              2                3  ...    100     115
# 8              2              2                0  ...     47      47
# 9              2              3               -1  ...     51      48
# 10             3              5               -2  ...     56      38
# 11             6              3                3  ...     69      85
# 12             3              4               -1  ...     52      34
# 13             1              1                0  ...     40      28
# 14             1              3               -2  ...     28      23
# 15             4              3                1  ...     58      36
# 16             9              3                6  ...     41      46
# 17             6              5                1  ...     26      27
# 18             3             11               -8  ...     24      37
# 19             4              1                3  ...     96      81
# 20             4              1                3  ...     90      90
# 21             1              2               -1  ...     30      35
# 22             2              7               -5  ...     33      37
# 23             3              1                2  ...     63      74
# 24             4              3                1  ...     53      49
# 25             4              4                0  ...     32      38
# 26             5              8               -3  ...     43      28
# 27             6              4                2  ...     55      65
# 28             4              4                0  ...     45      34
# 29             2              2                0  ...     34      36
# 30             5              7               -2  ...     46      38
#
#     offsides  pens_won  pens_conceded  own_goals  ball_recoveries  \
# 0          8         0              1          0              241
# 1          8         1              0          0              192
# 2          8         1              1          0              135
# 3          7         0              1          0              138
# 4          5         2              1          0              227
# 5          5         0              1          0              212
# 6          4         1              0          0              147
# 7         23         5              2          1              357
# 8          1         1              2          0              164
# 9         13         0              1          0              151
# 10         3         1              1          0              132
# 11        16         1              4          0              364
# 12         1         0              0          0              200
# 13         7         0              0          0              170
# 14         5         0              0          0              171
# 15         9         0              1          0              220
# 16        11         1              0          0              225
# 17        12         1              0          0              164
# 18        13         0              1          0              142
# 19        19         0              0          1              369
# 20        11         0              1          0              409
# 21         3         0              1          0              132
# 22         8         0              0          0              145
# 23         8         1              0          0              271
# 24         6         0              0          0              190
# 25         2         0              0          0              142
# 26         4         0              0          0              161
# 27        14         1              0          0              256
# 28         7         0              1          0              175
# 29         3         0              2          0              166
# 30         4         1              1          0              146
#
#     aerials_won  aerials_lost  aerials_won_pct
# 0            79            70             53.0
# 1            72            63             53.3
# 2            50            49             50.5
# 3            36            38             48.6
# 4            60            66             47.6
# 5            53            53             50.0
# 6            42            41             50.6
# 7            83            90             48.0
# 8            51            60             45.9
# 9            48            51             48.5
# 10           45            49             47.9
# 11          106            78             57.6
# 12           72            72             50.0
# 13           48            57             45.7
# 14           51            48             51.5
# 15           59            76             43.7
# 16           41            39             51.3
# 17           36            33             52.2
# 18           38            30             55.9
# 19           70            85             45.2
# 20           87            87             50.0
# 21           33            28             54.1
# 22           30            21             58.8
# 23           43            56             43.4
# 24           45            49             47.9
# 25           42            36             53.8
# 26           43            38             53.1
# 27           66            53             55.5
# 28           72            59             55.0
# 29           53            47             53.0
# 30           36            62             36.7
#
# [31 rows x 203 columns]

# %%
total_goals = df_merged['goals_scored'].sum()
average_goals = df_merged['goals_scored'].mean()
total_matches = df_merged['matches_played'].sum()

# %%
def generate_metric(title, value):
    return html.Div(
        [
            html.H5(title, className="metric-title"),
            html.H3(value, className="metric-value"),
        ],
        className="metric"
    )

def generate_graph(figure):
    return dcc.Graph(figure=figure)

# Dashboard
app_fifa_dash.layout = html.Div([
    html.Div([
        html.H2("FIFA World Cup Dashboard", className="dashboard-title")
    ]),
    html.Div([
        generate_metric("Total Goals Scored", total_goals),
        generate_metric("Average Goals Per Match", f"{average_goals:.2f}"),
        generate_metric("Total Matches Played", total_matches),
    ], className="row metrics-row"),
    html.Div([
        generate_graph(px.pie(df_merged, names='team')),
        generate_graph(px.bar(df_merged, x='team', y='goals_scored')),
        generate_graph(px.scatter(df_merged, x='team', y='goals_scored')),
    ], className="row charts-row"),
    # More rows and components here
], className="dashboard")

# Run the app
if __name__ == '__main__':
    app_fifa_dash.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
team_options = [{'label': team, 'value': team} for team in df_merged['team'].unique()]

app_fifa_dash.layout = html.Div([
    dcc.Dropdown(
        id='team1-dropdown',
        options=team_options,
        value=team_options[0]['value']
    ),

    dcc.Dropdown(
        id='team2-dropdown',
        options=team_options,
        value=team_options[1]['value']
    ),

    dcc.Graph(id='comparison-graph')
])

# Callback to update the graph based on the selected teams
@app_fifa_dash.callback(
    Output('comparison-graph', 'figure'),
    [Input('team1-dropdown', 'value'),
     Input('team2-dropdown', 'value')]
)
def update_graph(team1, team2):
    # Filter data for the selected teams
    filtered_data = df_merged[df_merged['team'].isin([team1, team2])]

    # Create a plotly express graph for the comparison
    bar_graph = px.bar(filtered_data, x='team', y='goals_scored')

    return bar_graph

# Run the app
if __name__ == '__main__':
    app_fifa_dash.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[91], line 36
#      34 # Run the app
#      35 if __name__ == '__main__':
# ---> 36     app_fifa_dash.run_server(debug=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/dash/dash.py:2246, in Dash.run_server(self, *args, **kwargs)
#    2240 def run_server(self, *args, **kwargs):
#    2241     """`run_server` is a deprecated alias of `run` and may be removed in a
#    2242     future version. We recommend using `app.run` instead.
#    2243
#    2244     See `app.run` for usage information.
#    2245     """
# -> 2246     self.run(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/dash/dash.py:2068, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2065 if debug is None:
#    2066     debug = get_combined_config("debug", None, False)
# -> 2068 debug = self.enable_dev_tools(
#    2069     debug,
#    2070     dev_tools_ui,
#    2071     dev_tools_props_check,
#    2072     dev_tools_serve_dev_bundles,
#    2073     dev_tools_hot_reload,
#    2074     dev_tools_hot_reload_interval,
#    2075     dev_tools_hot_reload_watch_interval,
#    2076     dev_tools_hot_reload_max_retry,
#    2077     dev_tools_silence_routes_logging,
#    2078     dev_tools_prune_errors,
#    2079 )
#    2081 # Verify port value
#    2082 try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/dash/dash.py:1838, in Dash.enable_dev_tools(self, debug, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors)
#    1836 if debug:
#    1837     if jupyter_dash.active:
# -> 1838         jupyter_dash.configure_callback_exception_handling(
#    1839             self, dev_tools.prune_errors
#    1840         )
#    1841     elif dev_tools.prune_errors:
#    1842         secret = gen_salt(20)
#
# File ~/Library/Python/3.9/lib/python/site-packages/dash/_jupyter.py:446, in JupyterDash.configure_callback_exception_handling(self, app, dev_tools_prune_errors)
#     443 def configure_callback_exception_handling(self, app, dev_tools_prune_errors):
#     444     """Install traceback handling for callbacks"""
# --> 446     @app.server.errorhandler(Exception)
#     447     def _wrap_errors(error):
#     448         # Compute number of stack frames to skip to get down to callback
#     449         skip = _get_skip(error) if dev_tools_prune_errors else 0
#     451         # Customized formatargvalues function we can place function parameters
#     452         # on separate lines
#
# File ~/Library/Python/3.9/lib/python/site-packages/flask/sansio/scaffold.py:45, in setupmethod.<locals>.wrapper_func(self, *args, **kwargs)
#      44 def wrapper_func(self: Scaffold, *args: t.Any, **kwargs: t.Any) -> t.Any:
# ---> 45     self._check_setup_finished(f_name)
#      46     return f(self, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/flask/sansio/app.py:419, in App._check_setup_finished(self, f_name)
#     417 def _check_setup_finished(self, f_name: str) -> None:
#     418     if self._got_first_request:
# --> 419         raise AssertionError(
#     420             f"The setup method '{f_name}' can no longer be called"
#     421             " on the application. It has already handled its first"
#     422             " request, any changes will not be applied"
#     423             " consistently.\n"
#     424             "Make sure all imports, decorators, functions, etc."
#     425             " needed to set up the application are done before"
#     426             " running it."
#     427         )
#
# AssertionError: The setup method 'errorhandler' can no longer be called on the application. It has already handled its first request, any changes will not be applied consistently.
# Make sure all imports, decorators, functions, etc. needed to set up the application are done before running it.

# %%
# Dash layout
app_covid_visualisation.layout = html.Div([
    html.H1("COVID-19 Data Visualization"),
    dcc.Dropdown(
        id='country-dropdown',
        options=[{'label': country, 'value': country} for country in countries],
        value='India'  # Default value # Make it to geo location 
    ),
    dcc.Graph(id='covid-graph')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       1 # Dash layout
#       2 app_covid_visualisation.layout = html.Div([
#       3     html.H1("COVID-19 Data Visualization"),
#       4     dcc.Dropdown(
#       5         id='country-dropdown',
# ----> 6         options=[{'label': country, 'value': country} for country in countries],
#       7         value='India'  # Default value # Make it to geo location
#       8     ),
#       9     dcc.Graph(id='covid-graph')
#      10 ])
#
# NameError: name 'countries' is not defined

# %%
# Callback for updating the graph
@app_covid_visualisation.callback(
    Output('covid-graph', 'figure'),
    [Input('country-dropdown', 'value')]
)
def update_graph(selected_country):
    filtered_df = df_covid[df_covid['Country/Region'] == selected_country]
    fig = px.line(filtered_df, x='Date', y='Confirmed', title=f'COVID-19 Confirmed Cases in {selected_country}')
    return fig

# %%
# Run the app
if __name__ == '__main__':
    app_fifa_dash.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
